# %% [markdown]
# <a href="https://colab.research.google.com/github/Versa03/data-science-toolkit/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
x = 1.5
print(x)
# Out:
# 1.5
